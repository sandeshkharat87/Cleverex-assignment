# %%
# unzipping dataset
# !unzip /content/drive/MyDrive/DRIVE_DATASETS/superstore_dataset.zip -d train_data
# Out:
# Archive:  /content/drive/MyDrive/DRIVE_DATASETS/superstore_dataset.zip
#   inflating: train_data/Superstore.csv
#   inflating: train_data/Superstore.xlsx

# %%
import pandas as pd

# %%
df =pd.read_excel("/content/train_data/Superstore.xlsx")

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# Row Id column not required so we dropped it
df.drop("Row ID",axis=1,inplace=True)

# %%
# renaming columns
df.rename(columns=lambda x:x.lower().replace(" ","_"),inplace=True)

# %%
df.sample(5)
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 6624  CA-2012-141250 2012-01-19 2012-01-23  Standard Class    PM-18940
# 881   CA-2012-129098 2012-10-09 2012-10-13  Standard Class    DK-13090
# 26    CA-2013-121755 2013-01-16 2013-01-20    Second Class    EH-13945
# 197   CA-2014-107720 2014-11-07 2014-11-14  Standard Class    VM-21685
# 4200  CA-2012-143105 2012-12-10 2012-12-10        Same Day    MA-17560
#
#         customer_name      segment        country           city       state  \
# 6624   Paul MacIntyre     Consumer  United States     Texas City       Texas
# 881         Dave Kipp     Consumer  United States    Springfield    Virginia
# 26      Eric Hoffmann     Consumer  United States    Los Angeles  California
# 197   Valerie Mitchum  Home Office  United States      Westfield  New Jersey
# 4200     Matt Abelman  Home Office  United States  New York City    New York
#
# ...

# %%
# checking null values
df.isnull().any()
# Out:
# order_id         False
# order_date       False
# ship_date        False
# ship_mode        False
# customer_id      False
# customer_name    False
# segment          False
# country          False
# city             False
# state            False
# postal_code      False
# region           False
# product_id       False
# category         False
# sub-category     False
# product_name     False
# sales            False
# quantity         False
# discount         False
# profit           False
# dtype: bool

# %%
# creating new column. later we are going to use this column for regression task
df["day"] = df["order_date"].dt.dayofweek
df["day_name"] = df["order_date"].dt.day_name()

# %%
# Cities which has highest sales
df.groupby("city")["sales"].sum().sort_values(ascending=False)
# Out:
# city
# New York City    256368.161
# Los Angeles      175851.341
# Seattle          119540.742
# San Francisco    112669.092
# Philadelphia     109077.013
#                     ...
# Ormond Beach          2.808
# Pensacola             2.214
# Jupiter               2.064
# Elyria                1.824
# Abilene               1.392
# Name: sales, Length: 531, dtype: float64

# %%
# city having highest sles -- done
# Most profitable product categories -- done
# In category which sub category is most profitable
# Most ~~not profitable product categories
# Sales by region
# Products which has lowest sells

# %%
import seaborn as sns

# %%
# Top 5 cities which has higeshtest sales
city_df = df.groupby("city")["sales"].sum().sort_values(ascending=False).head().reset_index()
# city_df
sns.barplot(data=city_df,x=city_df.city, y=city_df.sales )
# Out:
# <Axes: xlabel='city', ylabel='sales'>

# %%
# Most profitable product categories -- done
df.groupby("category")["profit"].sum().sort_values(ascending=False).plot(kind="pie",y="profit",autopct='%1.0f%%')
# Out:
# <Axes: ylabel='profit'>

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'customer_name', 'segment', 'country', 'city', 'state', 'postal_code',
#        'region', 'product_id', 'category', 'sub-category', 'product_name',
#        'sales', 'quantity', 'discount', 'profit', 'day', 'day_name'],
#       dtype='object')

# %%
# Here we can see that category "Tables","Bookcases","Supplies" not making profit , profit is in minus
# We shoud find here why they are not making any prfit. then take descion where should we keep these categories or
# or find the cause.
df.groupby(["category","sub-category"])["profit"].sum().sort_values(ascending=True).reset_index()
# Out:
#            category sub-category      profit
# 0         Furniture       Tables -17725.4811
# 1         Furniture    Bookcases  -3472.5560
# 2   Office Supplies     Supplies  -1189.0995
# 3   Office Supplies    Fasteners    949.5182
# 4        Technology     Machines   3384.7569
# 5   Office Supplies       Labels   5546.2540
# 6   Office Supplies          Art   6527.7870
# 7   Office Supplies    Envelopes   6964.1767
# 8         Furniture  Furnishings  13059.1436
# 9   Office Supplies   Appliances  18138.0054
# 10  Office Supplies      Storage  21278.8264
# 11        Furniture       Chairs  26590.1663
# 12  Office Supplies      Binders  30221.7633
# 13  Office Supplies        Paper  34053.5693
# 14       Technology  Accessories  41936.6357
# 15       Technology       Phones  44515.7306
# 16       Technology      Copiers  55617.8249

# %%
"""
Customer who bought most products vs. Customer who generated salese by purchsing products
"""
# df.groupby(["customer_name","product_name"])["sales"].sum()
df.groupby(["customer_name"])["product_name"].apply(list).apply(len).sort_values(ascending=False).head().reset_index().plot(kind="bar",x="customer_name")
plt.show()
df.groupby(["customer_name"])["sales"].sum().sort_values(ascending=False).head().reset_index().plot(kind="bar",x="customer_name")
# Out:
# <Axes: xlabel='customer_name'>

# %%
# showing column => "category","sub-category" sales and profit
df.groupby(["category","sub-category",])["sales","profit"].sum()
# Out:
# <ipython-input-122-ae4c8730abcf>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["category","sub-category"])["sales","profit"].sum()
#                                     sales      profit
# category        sub-category
# Furniture       Bookcases     114879.9963  -3472.5560
#                 Chairs        328449.1030  26590.1663
#                 Furnishings    91705.1640  13059.1436
#                 Tables        206965.5320 -17725.4811
# Office Supplies Appliances    107532.1610  18138.0054
#                 Art            27118.7920   6527.7870
#                 Binders       203412.7330  30221.7633
#                 Envelopes      16476.4020   6964.1767
#                 Fasteners       3024.2800    949.5182
#                 Labels         12486.3120   5546.2540
#                 Paper          78479.2060  34053.5693
#                 Storage       223843.6080  21278.8264
# ...

# %%
# Showing on which day most products are ordred

"""
Insight: On Sundays, we see that fewer products are ordered. However, since Saturday and Sunday are holidays, most people would be free on these days.
We can offer coupons or discounts to customers who buy on Saturdays and Sundays to attract more people.
"""

temp_df = df.groupby("day_name")["product_name"].count().reset_index()
sns.barplot(temp_df, x="day_name",y="product_name")
# Out:
# <Axes: xlabel='day_name', ylabel='product_name'>

# %%
# Showing on which day most sales are generated
temp_df = df.groupby("day_name")["sales"].sum().reset_index()
sns.barplot(temp_df, x="day_name",y="sales")
# Out:
# <Axes: xlabel='day_name', ylabel='sales'>

# %%
df.sample(3)
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 5989  CA-2013-163776 2013-07-20 2013-07-26  Standard Class    JS-16030
# 1978  CA-2012-109939 2012-05-08 2012-05-12  Standard Class    AA-10375
# 3062  CA-2012-145184 2012-11-27 2012-11-29     First Class    JD-16150
#
#          customer_name    segment        country         city        state  \
# 5989         Joy Smith   Consumer  United States  Hattiesburg  Mississippi
# 1978      Allen Armold   Consumer  United States        Salem       Oregon
# 3062  Justin Deggeller  Corporate  United States       Newark     Delaware
#
#       ...       product_id         category sub-category  \
# 5989  ...  FUR-BO-10003546        Furniture    Bookcases
# 1978  ...  OFF-AR-10000127  Office Supplies          Art
# 3062  ...  TEC-PH-10002350       Technology       Phones
#
#                            product_name    sales quantity  discount    profit  \
# ...

# %% [markdown]
#  ### Task: Predicting Sales Values

# %%
# Take only required columns for prediction
req_cols = ["ship_mode","segment","category","state", "day","quantity","discount", "profit","sub-category" ,"sales"]

# %%
final_df = df[req_cols]

# %%
final_df
# Out:
#            ship_mode    segment         category       state  day  quantity  \
# 0       Second Class   Consumer        Furniture    Kentucky    5         2
# 1       Second Class   Consumer        Furniture    Kentucky    5         3
# 2       Second Class  Corporate  Office Supplies  California    3         2
# 3     Standard Class   Consumer        Furniture     Florida    3         5
# 4     Standard Class   Consumer  Office Supplies     Florida    3         2
# ...              ...        ...              ...         ...  ...       ...
# 9989    Second Class   Consumer        Furniture     Florida    5         3
# 9990  Standard Class   Consumer        Furniture  California    3         2
# 9991  Standard Class   Consumer       Technology  California    3         2
# 9992  Standard Class   Consumer  Office Supplies  California    3         4
# 9993    Second Class   Consumer  Office Supplies  California    0         2
#
#       discount    profit sub-category     sales
# ...

# %%
# categorical columns
cata_cols = ["ship_mode", "segment", "category", "state", "sub-category"]

# %%
df2 = pd.get_dummies(final_df, columns=cata_cols,drop_first=True)

# %%
df2
# Out:
#       day  quantity  discount    profit     sales  ship_mode_Same Day  \
# 0       5         2      0.00   41.9136  261.9600                   0
# 1       5         3      0.00  219.5820  731.9400                   0
# 2       3         2      0.00    6.8714   14.6200                   0
# 3       3         5      0.45 -383.0310  957.5775                   0
# 4       3         2      0.20    2.5164   22.3680                   0
# ...   ...       ...       ...       ...       ...                 ...
# 9989    5         3      0.20    4.1028   25.2480                   0
# 9990    3         2      0.00   15.6332   91.9600                   0
# 9991    3         2      0.20   19.3932  258.5760                   0
# 9992    3         4      0.00   13.3200   29.6000                   0
# 9993    0         2      0.00   72.9480  243.1600                   0
#
#       ship_mode_Second Class  ship_mode_Standard Class  segment_Corporate  \
# ...

# %%
X = df2.drop("sales",1)
Y = df2["sales"]
# Out:
# <ipython-input-210-66ab2cfc90d5>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = df2.drop("sales",1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
sc = StandardScaler()

# %%
# Splitting dataset in to 70-30
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.30)

# %%
x_train.shape
y_train.shape
# Out:
# (6995,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

lr =  LinearRegression()
rf_lr =  RandomForestRegressor()
sv_lr =  SVR()

# %%
# Random Forrest gave better Accuracy 78%
for k,v in {"linear_regrssion":lr, "Random_forrest":rf_lr,"SVM": sv_lr}.items():
    v.fit(x_train,y_train)
    score = v.score(x_test,y_test)*100
    print(k,"=",score)
# Out:
# linear_regrssion = 46.26625088968848
# Random_forrest = 78.20128945322281
# SVM = 15.449038204863596
